# %% [markdown]
# # Section 4 Pandas

# %% [markdown]
# ## Introduction

# %% [markdown]
# ---

# %% [markdown]
# ## Series

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']

# %%
mylist = [10, 20, 30]

# %%
arr = np.array(mylist)

# %%
arr
# Out:
# array([10, 20, 30])

# %%
d = {'a':10, "b":20, "c":30}

# %%
pd.Series(data=mylist)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
pd.Series(data=arr, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
pd.Series(data=[10,'a',4.4])
# Out:
# 0     10
# 1      a
# 2    4.4
# dtype: object

# %%
pd.Series(data=['d','a','e'])
# Out:
# 0    d
# 1    a
# 2    e
# dtype: object

# %%
ser1 = pd.Series([1,2,3,4],index=['USA','Germany','USSR','Japan'])

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser1['USA']
# Out:
# 1

# %%
ser2= pd.Series([1, 4, 5, 6], index=['USA', 'Germany', 'Italy', 'Japan'])

# %%
ser2
# Out:
# USA        1
# Germany    4
# Italy      5
# Japan      6
# dtype: int64

# %%
ser1 + ser2
# Out:
# Germany     6.0
# Italy       NaN
# Japan      10.0
# USA         2.0
# USSR        NaN
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Dataframes  - Part One

# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn
np.random.seed(101)

rand_mat = randn(5,4)

# %%
rand_mat
# Out:
# array([[ 2.70684984,  0.62813271,  0.90796945,  0.50382575],
#        [ 0.65111795, -0.31931804, -0.84807698,  0.60596535],
#        [-2.01816824,  0.74012206,  0.52881349, -0.58900053],
#        [ 0.18869531, -0.75887206, -0.93323722,  0.95505651],
#        [ 0.19079432,  1.97875732,  2.60596728,  0.68350889]])

# %%
df = pd.DataFrame(data=rand_mat)
df
# Out:
#           0         1         2         3
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509

# %%
df = pd.DataFrame(data=rand_mat, index="A B C D E".split())
df
# Out:
#           0         1         2         3
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df = pd.DataFrame(data=rand_mat, index="A B C D E".split(), columns="W X Y Z".split())
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
mylist = ['W', 'Y']
df[mylist]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077
# C -2.018168  0.528813
# D  0.188695 -0.933237
# E  0.190794  2.605967

# %%
df[['W', 'Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077
# C -2.018168  0.528813
# D  0.188695 -0.933237
# E  0.190794  2.605967

# %%
df.W
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
df['NEW'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       NEW
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('NEW', axis=1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z       NEW
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('NEW', axis=1, inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.drop('A')
# Out:
#           W         X         Y         Z
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.drop('C')
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
# by location of row
df.loc['A']
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
# by integer location
df.iloc[0]
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df.iloc[2]
# Out:
# W   -2.018168
# X    0.740122
# Y    0.528813
# Z   -0.589001
# Name: C, dtype: float64

# %%
df.loc[['A', 'E']]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.iloc[[0,3]]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.loc[['A', 'B']][['Y','Z']]
# Out:
#           Y         Z
# A  0.907969  0.503826
# B -0.848077  0.605965

# %%
df.loc[['A', 'B'],['Y','Z']]
# Out:
#           Y         Z
# A  0.907969  0.503826
# B -0.848077  0.605965

# %% [markdown]
# ---

# %% [markdown]
# ## Dataframes - Part Two

# %%
df > 0
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df_bool = df>0

# %%
df[df_bool]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
# series of boolean values
df['W']>0
# Out:
# A     True
# B     True
# C    False
# D     True
# E     True
# Name: W, dtype: bool

# %%
# series of boolean values casted as selection/filter in df
df[df['W']>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['W']>0]['Y']
# Out:
# A    0.907969
# B   -0.848077
# D   -0.933237
# E    2.605967
# Name: Y, dtype: float64

# %%
df[df['W']>0]['Y'].loc['A']
# Out:
# 0.9079694464765431

# %%
cond1 = df['W'] > 0
cond2 = df['Y'] > 1

# %%
df[cond1 and cond2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9248\2218295925.py in <module>
# ----> 1 df[cond1 and cond2]
#
# ~\.conda\envs\tsa_course\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# needs to be & for and, | for or
# cause python operators is to check one boolean value, not a list/series, but pandas has it methods
df[(cond1) & (cond2)]
# Out:
#           W         X         Y         Z
# E  0.190794  1.978757  2.605967  0.683509

# %%
#it's the same as
df[(df['W'] > 0) & (df['Y'] > 1)]
# Out:
#           W         X         Y         Z
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
new_ind = 'CA NY WY OR CO'.split()

# %%
new_ind
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['States'] = new_ind
df
# Out:
#           W         X         Y         Z States
# A  2.706850  0.628133  0.907969  0.503826     CA
# B  0.651118 -0.319318 -0.848077  0.605965     NY
# C -2.018168  0.740122  0.528813 -0.589001     WY
# D  0.188695 -0.758872 -0.933237  0.955057     OR
# E  0.190794  1.978757  2.605967  0.683509     CO

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA      2.706850  0.628133  0.907969  0.503826
# NY      0.651118 -0.319318 -0.848077  0.605965
# WY     -2.018168  0.740122  0.528813 -0.589001
# OR      0.188695 -0.758872 -0.933237  0.955057
# CO      0.190794  1.978757  2.605967  0.683509

# %%
df.set_index('States', inplace=True)
df
# Out:
#                W         X         Y         Z
# States
# CA      2.706850  0.628133  0.907969  0.503826
# NY      0.651118 -0.319318 -0.848077  0.605965
# WY     -2.018168  0.740122  0.528813 -0.589001
# OR      0.188695 -0.758872 -0.933237  0.955057
# CO      0.190794  1.978757  2.605967  0.683509

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, CA to CO
# Data columns (total 4 columns):
# W    5 non-null float64
# X    5 non-null float64
# Y    5 non-null float64
# Z    5 non-null float64
# dtypes: float64(4)
# memory usage: 200.0+ bytes

# %%
df.dtypes
# Out:
# W    float64
# X    float64
# Y    float64
# Z    float64
# dtype: object

# %%
df.describe()
# Out:
#               W         X         Y         Z
# count  5.000000  5.000000  5.000000  5.000000
# mean   0.343858  0.453764  0.452287  0.431871
# std    1.681131  1.061385  1.454516  0.594708
# min   -2.018168 -0.758872 -0.933237 -0.589001
# 25%    0.188695 -0.319318 -0.848077  0.503826
# 50%    0.190794  0.628133  0.528813  0.605965
# 75%    0.651118  0.740122  0.907969  0.683509
# max    2.706850  1.978757  2.605967  0.955057

# %%
df['W'] > 0
# Out:
# States
# CA     True
# NY     True
# WY    False
# OR     True
# CO     True
# Name: W, dtype: bool

# %%
ser_w = df['W'] > 0

# %%
ser_w.value_counts()
# Out:
# True     4
# False    1
# Name: W, dtype: int64

# %%
sum(ser_w)
# Out:
# 4

# %%
len(ser_w)
# Out:
# 5

# %% [markdown]
# ---

# %% [markdown]
# ## Missing Data with Pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({"A":[1, 2, np.nan],"B":[5, np.nan, np.nan],"C":[1, 2, 3]})
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
#drop columns
df.dropna(axis=1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.dropna(thresh=2)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.fillna(value= 'FILL VALUE')
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.fillna(value=0)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  0.0  2
# 2  0.0  0.0  3

# %%
df.mean()
# Out:
# W    0.343858
# X    0.453764
# Y    0.452287
# Z    0.431871
# dtype: float64

# %%
df.fillna(value=df.mean())
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\tsa_course\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9248\740595337.py in <module>
# ----> 1 df['A'].fillna(value=df['A'].mean())
#
# ~\.conda\envs\tsa_course\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\.conda\envs\tsa_course\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\.conda\envs\tsa_course\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\.conda\envs\tsa_course\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\.conda\envs\tsa_course\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A'

# %% [markdown]
# ---

# %% [markdown]
# ## Group By Operations

# %%
import pandas as pd

# %%
# Create dataframe 
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
        'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarag'],
        'Sales':[200, 120, 340, 124, 243, 350]
        }

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarag    350

# %%
df.groupby('Company').mean()
# Out:
# C:\Users\BMonti\AppData\Local\Temp\ipykernel_11688\2058252646.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Company').mean()
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
df.groupby('Company').max()
# Out:
#           Person  Sales
# Company
# FB         Sarag    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
df.groupby('Company').std()
# Out:
# C:\Users\BMonti\AppData\Local\Temp\ipykernel_11688\2093150834.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Company').std()
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
df.groupby('Company').describe().T
# Out:
# Company              FB        GOOG        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %% [markdown]
# ---

# %% [markdown]
# ## Common Operations

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {'col1':[1, 2, 3, 4],
     'col2':[444, 555, 666, 444],
     'col3':['abc', 'def', 'ghi', 'xyz']
     }
)
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666], dtype=int64)

# %%
df['col2'].nunique()
# Out:
# 3

# %%
len(df['col2'].unique())
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
# Col 1 > 2
# Col  2 == 444
newdf = df[(df['col1'] > 2) & (df['col2'] == 444)]

# %%
newdf
# Out:
#    col1  col2 col3
# 3     4   444  xyz

# %%
def times_two(number):
    return number*2

# %%
times_two(4)
# Out:
# 8

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col1'].apply(times_two)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['new'] = df['col1'].apply(times_two)

# %%
df
# Out:
#    col1  col2 col3  new
# 0     1   444  abc    2
# 1     2   555  def    4
# 2     3   666  ghi    6
# 3     4   444  xyz    8

# %%
del df['new']

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    4 non-null      int64
#  1   col2    4 non-null      int64
#  2   col3    4 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#            col1        col2
# count  4.000000    4.000000
# mean   2.500000  527.250000
# std    1.290994  106.274409
# min    1.000000  444.000000
# 25%    1.750000  444.000000
# 50%    2.500000  499.500000
# 75%    3.250000  582.750000
# max    4.000000  666.000000

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.sort_values('col2')
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df.sort_values('col2', ascending=False)
# Out:
#    col1  col2 col3
# 2     3   666  ghi
# 1     2   555  def
# 0     1   444  abc
# 3     4   444  xyz

# %% [markdown]
# ---

# %% [markdown]
# ## Data Input and Output

# %%
import pandas as pd

# %%
pwd
# Out:
# 'f:\\Documentos\\GitHub\\-Re-Training\\Udemy\\Python for Time Series Data Analysis'

# %%
df = pd.read_csv('example.csv')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
new_df = df[['a','b']]

# %%
new_df.to_csv('mynew.csv', index=False)

# %%
df2 = pd.read_excel('Excel_Sample.xlsx', sheet_name='Sheet1')

# %%
df2
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df3 = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')
df3
# Out:
# [                               Bank Name               City          State  \
#  0     The First National Bank of Lindsay            Lindsay       Oklahoma
#  1  Republic First Bank dba Republic Bank       Philadelphia   Pennsylvania
#  2                          Citizens Bank           Sac City           Iowa
#  3               Heartland Tri-State Bank            Elkhart         Kansas
#  4                    First Republic Bank      San Francisco     California
#  5                         Signature Bank           New York       New York
#  6                    Silicon Valley Bank        Santa Clara     California
#  7                      Almena State Bank             Almena         Kansas
#  8             First City Bank of Florida  Fort Walton Beach        Florida
#  9                   The First State Bank      Barboursville  West Virginia
#
#      Cert                 Aquiring Institution      Closing Date  \
#  0   4134   First Bank & Trust Co., Duncan, OK  October 18, 2024
#  1  27332    Fulton Bank, National Association    April 26, 2024
#  2   8758            Iowa Trust & Savings Bank  November 3, 2023
#  3  25851               Dream First Bank, N.A.     July 28, 2023
#  4  59017            JPMorgan Chase Bank, N.A.       May 1, 2023
#  5  57053                  Flagstar Bank, N.A.    March 12, 2023
#  6  24735  First Citizens Bank & Trust Company    March 10, 2023
#  7  15426                          Equity Bank  October 23, 2020
#  8  16748            United Fidelity Bank, fsb  October 16, 2020
#  9  14361                       MVB Bank, Inc.     April 3, 2020
#
#     Fund  Sort ascending
#  0                 10547
#  1                 10546
#  2                 10545
#  3                 10544
#  4                 10543
#  5                 10540
#  6                 10539
#  7                 10538
#  8                 10537
#  9                 10536  ]

# %%
df3[0].head()
# Out:
#                                Bank Name           City         State   Cert  \
# 0     The First National Bank of Lindsay        Lindsay      Oklahoma   4134
# 1  Republic First Bank dba Republic Bank   Philadelphia  Pennsylvania  27332
# 2                          Citizens Bank       Sac City          Iowa   8758
# 3               Heartland Tri-State Bank        Elkhart        Kansas  25851
# 4                    First Republic Bank  San Francisco    California  59017
#
#                  Aquiring Institution      Closing Date  Fund  Sort ascending
# 0  First Bank & Trust Co., Duncan, OK  October 18, 2024                 10547
# 1   Fulton Bank, National Association    April 26, 2024                 10546
# 2           Iowa Trust & Savings Bank  November 3, 2023                 10545
# 3              Dream First Bank, N.A.     July 28, 2023                 10544
# 4           JPMorgan Chase Bank, N.A.       May 1, 2023                 10543

# %% [markdown]
# ---

# %% [markdown]
# ## Pandas Exercises

# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright Pierian Data</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Pandas Exercises
# Time to test your new pandas skills! Use the <tt>population_by_county.csv</tt> file in the Data folder to complete the tasks in bold below!
#
# <div class="alert alert-info" style="margin: 10px"><strong>NOTE:</strong> ALL TASKS CAN BE DONE IN ONE LINE OF PANDAS CODE. GET STUCK? NO PROBLEM! CHECK OUT THE SOLUTIONS LECTURE!</div>
#
# <div class="alert alert-danger" style="margin: 10px"><strong>IMPORTANT NOTE!</strong> Make sure you don't run the cells directly above the example output shown, <br>otherwise you will end up writing over the example output!</div>

# %% [markdown]
# #### 1. Import pandas and read in the <tt>population_by_county.csv</tt> file into a dataframe called <tt>pop</tt>.

# %%
import pandas as pd

# %%
pop = pd.read_csv(r"F:\Documentos\Udemy\Python for Time Series Data Analysis\UDEMY_TSA_FINAL\Data\population_by_county.csv")
pop
# Out:
#                          County           State  2010Census  2017PopEstimate
# 0              Abbeville County  South Carolina       25417            24722
# 1                 Acadia Parish       Louisiana       61773            62590
# 2               Accomack County        Virginia       33164            32545
# 3                    Ada County           Idaho      392365           456849
# 4                  Adair County            Iowa        7682             7054
# 5                  Adair County        Kentucky       18656            19485
# 6                  Adair County        Missouri       25607            25377
# 7                  Adair County        Oklahoma       22683            21909
# 8                  Adams County        Colorado      441603           503167
# 9                  Adams County           Idaho        3976             4147
# 10                 Adams County        Illinois       67103            66234
# 11                 Adams County         Indiana       34387            35491
# 12                 Adams County            Iowa        4029             3686
# 13                 Adams County     Mississippi       32297            31003
# 14                 Adams County        Nebraska       31364            31678
# 15                 Adams County    North Dakota        2343             2318
# 16                 Adams County            Ohio       28550            27726
# 17                 Adams County    Pennsylvania      101407           102336
# 18                 Adams County      Washington       18728            19506
# 19                 Adams County       Wisconsin       20875            19973
# 20               Addison County         Vermont       36821            36776
# 21                 Aiken County  South Carolina      160099           168179
# 22                Aitkin County       Minnesota       16202            15829
# 23               Alachua County         Florida      247336           266944
# 24              Alamance County  North Carolina      151131           162391
# 25               Alameda County      California     1510271          1663190
# 26               Alamosa County        Colorado       15445            16551
# 27                Albany County        New York      304204           309612
# 28                Albany County         Wyoming       36299            38332
# 29             Albemarle County        Virginia       98970           107702
# ...                         ...             ...         ...              ...
# 3112             Wyoming County   West Virginia       23796            21210
# 3113               Wythe County        Virginia       29235            28882
# 3114              Yadkin County  North Carolina       38406            37774
# 3115              Yakima County      Washington      243231           250193
# 3116   Yakutat City and Borough          Alaska         662              605
# 3117           Yalobusha County     Mississippi       12678            12497
# 3118             Yamhill County          Oregon       99193           105722
# 3119              Yancey County  North Carolina       17818            17744
# 3120             Yankton County    South Dakota       22438            22662
# 3121               Yates County        New York       25348            24955
# 3122             Yavapai County         Arizona      211033           228168
# 3123               Yazoo County     Mississippi       28065            27057
# 3124                Yell County        Arkansas       22185            21523
# 3125     Yellow Medicine County       Minnesota       10438             9867
# 3126         Yellowstone County         Montana      147972           158980
# 3127              Yoakum County           Texas        7879             8568
# 3128                Yolo County      California      200849           219116
# 3129                York County           Maine      197131           204191
# 3130                York County        Nebraska       13665            13806
# 3131                York County    Pennsylvania      434972           446078
# 3132                York County  South Carolina      226073           266439
# 3133                York County        Virginia       65464            67739
# 3134               Young County           Texas       18550            17979
# 3135                Yuba County      California       72155            77031
# 3136  Yukon-Koyukuk Census Area          Alaska        5588             5365
# 3137                Yuma County         Arizona      195751           207534
# 3138                Yuma County        Colorado       10043            10075
# 3139              Zapata County           Texas       14018            14322
# 3140              Zavala County           Texas       11677            11948
# 3141             Ziebach County    South Dakota        2801             2756
#
# [3142 rows x 4 columns]

# %% [markdown]
# #### 2. Show the head of the dataframe

# %%
# CODE HERE
pop.head()
# Out:
#              County           State  2010Census  2017PopEstimate
# 0  Abbeville County  South Carolina       25417            24722
# 1     Acadia Parish       Louisiana       61773            62590
# 2   Accomack County        Virginia       33164            32545
# 3        Ada County           Idaho      392365           456849
# 4      Adair County            Iowa        7682             7054

# %%
# DON'T WRITE HERE
# Out:
#              County           State  2010Census  2017PopEstimate
# 0  Abbeville County  South Carolina       25417            24722
# 1     Acadia Parish       Louisiana       61773            62590
# 2   Accomack County        Virginia       33164            32545
# 3        Ada County           Idaho      392365           456849
# 4      Adair County            Iowa        7682             7054

# %% [markdown]
# #### 3. What are the column names?

# %%
pop.columns
# Out:
# Index(['County', 'State', '2010Census', '2017PopEstimate'], dtype='object')

# %%
# DON'T WRITE HERE
# Out:
# Index(['County', 'State', '2010Census', '2017PopEstimate'], dtype='object')

# %% [markdown]
# <strong>4. How many States are represented in this data set?</strong> <em>Note: the data includes the District of Columbia</em>

# %%
pop['State'].nunique()
# Out:
# 51

# %%
# DON'T WRITE HERE
# Out:
# 51

# %% [markdown]
# #### 5. Get a list or array of all the states in the data set.

# %%
pop['State'].unique()
# Out:
# array(['South Carolina', 'Louisiana', 'Virginia', 'Idaho', 'Iowa',
#        'Kentucky', 'Missouri', 'Oklahoma', 'Colorado', 'Illinois',
#        'Indiana', 'Mississippi', 'Nebraska', 'North Dakota', 'Ohio',
#        'Pennsylvania', 'Washington', 'Wisconsin', 'Vermont', 'Minnesota',
#        'Florida', 'North Carolina', 'California', 'New York', 'Wyoming',
#        'Michigan', 'Alaska', 'Maryland', 'Kansas', 'Tennessee', 'Texas',
#        'Maine', 'Arizona', 'Georgia', 'Arkansas', 'New Jersey',
#        'South Dakota', 'Alabama', 'Oregon', 'West Virginia',
#        'Massachusetts', 'Utah', 'Montana', 'New Hampshire', 'New Mexico',
#        'Rhode Island', 'Nevada', 'District of Columbia', 'Connecticut',
#        'Hawaii', 'Delaware'], dtype=object)

# %%
# DON'T WRITE HERE
# Out:
# array(['South Carolina', 'Louisiana', 'Virginia', 'Idaho', 'Iowa',
#        'Kentucky', 'Missouri', 'Oklahoma', 'Colorado', 'Illinois',
#        'Indiana', 'Mississippi', 'Nebraska', 'North Dakota', 'Ohio',
#        'Pennsylvania', 'Washington', 'Wisconsin', 'Vermont', 'Minnesota',
#        'Florida', 'North Carolina', 'California', 'New York', 'Wyoming',
#        'Michigan', 'Alaska', 'Maryland', 'Kansas', 'Tennessee', 'Texas',
#        'Maine', 'Arizona', 'Georgia', 'Arkansas', 'New Jersey',
#        'South Dakota', 'Alabama', 'Oregon', 'West Virginia',
#        'Massachusetts', 'Utah', 'Montana', 'New Hampshire', 'New Mexico',
#        'Rhode Island', 'Nevada', 'District of Columbia', 'Connecticut',
#        'Hawaii', 'Delaware'], dtype=object)

# %% [markdown]
# #### 6. What are the five most common County names in the U.S.?

# %%
pop['County'].value_counts().head()
# Out:
# Washington County    30
# Jefferson County     25
# Franklin County      24
# Jackson County       23
# Lincoln County       23
# Name: County, dtype: int64

# %%
pop.groupby('County')['State'].count().sort_values(ascending=False).head()
# Out:
# County
# Washington County    30
# Jefferson County     25
# Franklin County      24
# Lincoln County       23
# Jackson County       23
# Name: State, dtype: int64

# %%
pop.groupby('County')['State'].count().sort_values(ascending=False)[:5]
# Out:
# County
# Washington County    30
# Jefferson County     25
# Franklin County      24
# Lincoln County       23
# Jackson County       23
# Name: State, dtype: int64

# %%
# DON'T WRITE HERE
# Out:
# Washington County    30
# Jefferson County     25
# Franklin County      24
# Jackson County       23
# Lincoln County       23
# Name: County, dtype: int64

# %% [markdown]
# #### 7. What are the top 5 most populated Counties according to the 2010 Census?

# %%
pop.sort_values('2010Census', ascending=False).head()
# Out:
#                   County       State  2010Census  2017PopEstimate
# 1713  Los Angeles County  California     9818605         10163507
# 628          Cook County    Illinois     5194675          5211263
# 1209       Harris County       Texas     4092459          4652980
# 1784     Maricopa County     Arizona     3817117          4307033
# 2501    San Diego County  California     3095313          3337685

# %%
# DON'T WRITE HERE
# Out:
#                   County       State  2010Census  2017PopEstimate
# 1713  Los Angeles County  California     9818605         10163507
# 628          Cook County    Illinois     5194675          5211263
# 1209       Harris County       Texas     4092459          4652980
# 1784     Maricopa County     Arizona     3817117          4307033
# 2501    San Diego County  California     3095313          3337685

# %% [markdown]
# #### 8. What are the top 5 most populated States according to the 2010 Census?

# %%
pop.groupby('State').sum().sort_values('2010Census', ascending=False).head()
# Out:
#             2010Census  2017PopEstimate
# State
# California    37253956         39536653
# Texas         25145561         28304596
# New York      19378102         19849399
# Florida       18801310         20984400
# Illinois      12830632         12802023

# %%
# DON'T WRITE HERE
# Out:
#             2010Census  2017PopEstimate
# State
# California    37253956         39536653
# Texas         25145561         28304596
# New York      19378102         19849399
# Florida       18801310         20984400
# Illinois      12830632         12802023

# %% [markdown]
# #### 9. How many Counties have 2010 populations greater than 1 million?

# %%
sum(pop['2010Census']>1000000)
# Out:
# 39

# %%
# DON'T WRITE HERE
# Out:
# 39

# %% [markdown]
# #### 10. How many Counties don't have the word "County" in their name?

# %%
sum(pop['County'].apply(lambda name: 'County' not in name))
# Out:
# 135

# %%
# DON'T WRITE HERE
# Out:
# 135

# %% [markdown]
# #### 11. Add a column that calculates the percent change between the 2010 Census and the 2017 Population Estimate

# %%
# CODE HERE
pop['PercentChange'] = ((pop['2017PopEstimate']-pop['2010Census'])/pop['2010Census'])*100
# USE THIS TO SHOW THE RESULT
pop.head()
# Out:
#              County           State  2010Census  2017PopEstimate  \
# 0  Abbeville County  South Carolina       25417            24722
# 1     Acadia Parish       Louisiana       61773            62590
# 2   Accomack County        Virginia       33164            32545
# 3        Ada County           Idaho      392365           456849
# 4      Adair County            Iowa        7682             7054
#
#    PercentChange
# 0      -2.734390
# 1       1.322584
# 2      -1.866482
# 3      16.434697
# 4      -8.174954

# %%
# DON'T WRITE HERE
# Out:
#              County           State  2010Census  2017PopEstimate  \
# 0  Abbeville County  South Carolina       25417            24722
# 1     Acadia Parish       Louisiana       61773            62590
# 2   Accomack County        Virginia       33164            32545
# 3        Ada County           Idaho      392365           456849
# 4      Adair County            Iowa        7682             7054
#
#    PercentChange
# 0      -2.734390
# 1       1.322584
# 2      -1.866482
# 3      16.434697
# 4      -8.174954

# %% [markdown]
# <strong>Bonus: What States have the highest estimated percent change between the 2010 Census and the 2017 Population Estimate?</strong><br>This will take several lines of code, as it requires a recalculation of PercentChange.

# %%
# CODE HERE
gpop = pop.groupby('State').sum()
gpop['PercentChange'] = ((gpop['2017PopEstimate']-gpop['2010Census'])/gpop['2010Census'])*100
gpop.sort_values('PercentChange', ascending=False).head()
# Out:
#                       2010Census  2017PopEstimate  PercentChange
# State
# District of Columbia      601723           693972      15.330808
# Texas                   25145561         28304596      12.562993
# North Dakota              672591           755393      12.310899
# Utah                     2763885          3101833      12.227282
# Florida                 18801310         20984400      11.611372

# %%
# DON'T WRITE HERE
# Out:
#                       2010Census  2017PopEstimate  PercentChange
# State
# District of Columbia      601723           693972      15.330808
# Texas                   25145561         28304596      12.562993
# North Dakota              672591           755393      12.310899
# Utah                     2763885          3101833      12.227282
# Florida                 18801310         20984400      11.611372

# %% [markdown]
# # GREAT JOB!

# %% [markdown]
# ---
